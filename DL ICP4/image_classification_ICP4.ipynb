# %% [markdown]
# # Simple CNN model for CIFAR-10

# %%
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Input, BatchNormalization
from keras.constraints import maxnorm
from keras.models import Model
from keras.optimizers import SGD, Adam
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.common.image_dim_ordering()
# Out:
# Using TensorFlow backend.
# 'tf'

# %% [markdown]
# fix random seed for reproducibility

# %%
seed = 7
numpy.random.seed(seed)

# %% [markdown]
# load data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# normalize inputs from 0-255 to 0.0-1.0

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
yp=y_test

# %% [markdown]
# one hot encode outputs

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %% [markdown]
# Create the model

# %%
model = Sequential()
model.add(Conv2D(128, (3, 3), input_shape=(X_train.shape[1:]), padding='same', activation='relu'))
model.add(Dropout(0.5))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# Compile model

# %%
epochs = 70
lrate = 0.001
decay = lrate/epochs
sgd = Adam(lr=lrate)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       3584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               33554944
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 33,858,826
# Trainable params: 33,858,826
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Fit the model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=128)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/70
# 50000/50000 [==============================] - 52s 1ms/step - loss: 1.8421 - accuracy: 0.3316 - val_loss: 1.4107 - val_accuracy: 0.4955
# Epoch 2/70
# 50000/50000 [==============================] - 45s 901us/step - loss: 1.3948 - accuracy: 0.4993 - val_loss: 1.2169 - val_accuracy: 0.5632
# Epoch 3/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 1.2349 - accuracy: 0.5642 - val_loss: 1.1052 - val_accuracy: 0.6128
# Epoch 4/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 1.1058 - accuracy: 0.6086 - val_loss: 0.9918 - val_accuracy: 0.6475
# Epoch 5/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 1.0178 - accuracy: 0.6388 - val_loss: 0.9424 - val_accuracy: 0.6699
# Epoch 6/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.9498 - accuracy: 0.6635 - val_loss: 0.9163 - val_accuracy: 0.6802
# Epoch 7/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.8985 - accuracy: 0.6796 - val_loss: 0.8891 - val_accuracy: 0.6908
# Epoch 8/70
# 50000/50000 [==============================] - 45s 901us/step - loss: 0.8563 - accuracy: 0.6978 - val_loss: 0.8611 - val_accuracy: 0.7028
# Epoch 9/70
# 50000/50000 [==============================] - 45s 901us/step - loss: 0.8190 - accuracy: 0.7121 - val_loss: 0.8677 - val_accuracy: 0.7005
# Epoch 10/70
# 50000/50000 [==============================] - 45s 901us/step - loss: 0.7949 - accuracy: 0.7209 - val_loss: 0.8474 - val_accuracy: 0.7042
# Epoch 11/70
# 50000/50000 [==============================] - 45s 901us/step - loss: 0.7646 - accuracy: 0.7293 - val_loss: 0.8225 - val_accuracy: 0.7147
# Epoch 12/70
# 50000/50000 [==============================] - 45s 903us/step - loss: 0.7450 - accuracy: 0.7352 - val_loss: 0.8205 - val_accuracy: 0.7151
# Epoch 13/70
# 50000/50000 [==============================] - 45s 903us/step - loss: 0.7212 - accuracy: 0.7451 - val_loss: 0.8485 - val_accuracy: 0.7058
# Epoch 14/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.7094 - accuracy: 0.7478 - val_loss: 0.8111 - val_accuracy: 0.7126
# Epoch 15/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.6847 - accuracy: 0.7576 - val_loss: 0.8005 - val_accuracy: 0.7199
# Epoch 16/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.6692 - accuracy: 0.7643 - val_loss: 0.8006 - val_accuracy: 0.7184
# Epoch 17/70
# 50000/50000 [==============================] - 45s 902us/step - loss: 0.6507 - accuracy: 0.7711 - val_loss: 0.8052 - val_accuracy: 0.7225
# Epoch 18/70
# 50000/50000 [==============================] - 45s 903us/step - loss: 0.6398 - accuracy: 0.7742 - val_loss: 0.8040 - val_accuracy: 0.7188
# Epoch 19/70
# 50000/50000 [==============================] - 45s 903us/step - loss: 0.6164 - accuracy: 0.7796 - val_loss: 0.7988 - val_accuracy: 0.7224
# Epoch 20/70
# 50000/50000 [==============================] - 45s 904us/step - loss: 0.6050 - accuracy: 0.7882 - val_loss: 0.8074 - val_accuracy: 0.7198
# Epoch 21/70
# 50000/50000 [==============================] - 45s 903us/step - loss: 0.5931 - accuracy: 0.7888 - val_loss: 0.8077 - val_accuracy: 0.7176
# Epoch 22/70
# 50000/50000 [==============================] - 45s 904us/step - loss: 0.5855 - accuracy: 0.7928 - val_loss: 0.8095 - val_accuracy: 0.7203
# Epoch 23/70
# 50000/50000 [==============================] - 45s 907us/step - loss: 0.5825 - accuracy: 0.7924 - val_loss: 0.7998 - val_accuracy: 0.7243
# Epoch 24/70
# 50000/50000 [==============================] - 45s 906us/step - loss: 0.5836 - accuracy: 0.7922 - val_loss: 0.8180 - val_accuracy: 0.7146
# Epoch 25/70
# 50000/50000 [==============================] - 45s 907us/step - loss: 0.5612 - accuracy: 0.8022 - val_loss: 0.8079 - val_accuracy: 0.7217
# Epoch 26/70
# 50000/50000 [==============================] - 45s 906us/step - loss: 0.5588 - accuracy: 0.8015 - val_loss: 0.8152 - val_accuracy: 0.7180
# Epoch 27/70
# 10112/50000 [=====>........................] - ETA: 34s - loss: 0.4904 - accuracy: 0.8253

# %% [markdown]
# Final evaluation of the model

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# %% [markdown]
# 1. Performance Change

# %%
m1 = Sequential()
m1.add(Conv2D(32, (3, 3), input_shape=(X_train.shape[1:]), padding='same', activation='relu'))
m1.add(Dropout(0.2))
m1.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
m1.add(MaxPooling2D(pool_size=(2, 2)))
m1.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
m1.add(Dropout(0.2))
m1.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
m1.add(MaxPooling2D(pool_size=(2, 2)))
m1.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
m1.add(Dropout(0.2))
m1.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
m1.add(MaxPooling2D(pool_size=(2, 2)))
m1.add(Flatten())
m1.add(Dropout(0.2))
m1.add(Dense(1024, activation='relu', kernel_constraint=maxnorm(3)))
m1.add(Dropout(0.2))
m1.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
m1.add(Dropout(0.2))
m1.add(Dense(num_classes, activation='softmax'))

# %%
epochs = 20
lrate = 0.001
decay = lrate/epochs
sgd = Adam(lr=lrate)
m1.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
print(m1.summary())

# %%
m1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=128)

# %%
scores = m1.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# %% [markdown]
# 2. Model to Keras API Model

# %%
print(X_train.shape[1:])

# %%
from keras.models import Model
from keras.layers import Input

visible = Input(shape=(32,32,3))
x=Conv2D(32,(3,3),padding="same",activation='relu')(visible)
x=Dropout(0.2)(x)
x=Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x=MaxPooling2D(pool_size=(2, 2))(x)
x=Dropout(0.5)(x)
x=Flatten()(x)
x=Dense(512, activation='relu', kernel_constraint=maxnorm(3))(x)
x=Dropout(0.3)(x)
x=Dense(num_classes, activation='softmax')(x)
m2 = Model(inputs=visible,output=x)

# %%
epochs = 20
lrate = 0.001
decay = lrate/epochs
sgd = Adam(lr=lrate)
m2.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
m2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=128)

# %% [markdown]
# 3. Predicting the first four images of dataset

# %%
y=model.predict_classes(X_train[[1],:])
print(y[0])

# %%
import matplotlib.pyplot as plt
for i in range(1,5):
  plt.imshow(X_test[i,:,:])  
  plt.show()
  y=model.predict_classes(X_test[[i],:])
  print("actual",yp[i],"predicted",y[0])
